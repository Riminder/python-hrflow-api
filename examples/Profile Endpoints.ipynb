# %% [markdown]
# # Install hrflow

# %%
# !pip3 install hrflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: hrflow in /usr/local/lib/python3.6/dist-packages (1.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from hrflow) (2.22.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.6/dist-packages/python_magic-0.4.15-py3.6.egg (from hrflow) (0.4.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->hrflow) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->hrflow) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->hrflow) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->hrflow) (3.0.4)

# %% [markdown]
# # Import hrflow

# %%
import hrflow as hf

# %% [markdown]
# # Launch hrflow Client

# %%
client = hf.Client(api_secret="secret_api_key")

# %% [markdown]
# # POST /profile

# %% [markdown]
# ## Json

# %%
# %%time
profile_data ={
            "name": "Hari Seldon",
            "email": "harisledon@trantor.trt",
            "address": "1 rue streeling",
            "info" : {"name":"name info", "email":"tata","phone":"0202","location":"somewhere","urls": {"from_resume": [], "linkedin":"","twitter":"","facebook":"","github":"","picture":""},"location":{"text":""}},
            "summary": "test summary",
            "experiences": [
              {
                "start": "15/02/12600",
                "end": "",
                "title": "Lead",
                "company": "Departement de la psychohistoire",
                "location": {"text":"Trator"},
                "description": "Developping psychohistoire."
              }
            ],
            "educations": [
              {
                "start": "12540",
                "end": "12550",
                "title": "Diplome d'ingénieur mathematicien",
                "school": "Université de Hélicon",
                "description": "Etude des mathematique",
                "location": {"text":"Hélicon"}
              }
            ],
            "skills": [
              "manual skill",
              "Creative spirit",
              "Writing skills",
              "Communication",
              "Project management",
              "French",
              "German",
              "Korean",
              "English",
              "Esquive",
              "Research",
              "Mathematique"
            ],
           "languages" : ["arab"],
           "interests": ["football"],
          "tags":[],
          "metadatas":[],
          "labels":[]
          }
res = client.profile.add_json(source_id="a62ae2d5560fca7b34bb6c0c389a378f99bcdd52", 
                              profile_json=profile_data,
                              profile_tags =[{"name": "email", "value":"test@test.com"}])
res
# Out:
# CPU times: user 18.5 ms, sys: 3.77 ms, total: 22.3 ms
# Wall time: 1 s
# {'code': 201,
#  'message': 'Profile file added',
#  'data': {'item_id': '657646bc2fbaf026d564c2158760549799bb4669',
#   'item_type': 'json'}}

# %% [markdown]
# ## Binary

# %%
with open("path/to/file","rb") as file:
    profile_binary = file.read()
res = client.profile.add_file(source_id="a62ae2d5560fca7b34bb6c0c389a378f99bcdd52",
                              sync_parsing=0,
                              profile_content_type='application/pdf',
                              profile_file=profile_binary,
                              profile_tags=[{"name": "email", "value":"test@test.com"}])
res
# Out:
# {'code': 201,
#  'message': 'Profile file added',
#  'data': {'item_id': '726706303032c3b316cee43d7cba61cc4d6a5265',
#   'item_type': 'file'}}

# %% [markdown]
# # GET /profil/attachment

# %%
# %%time
client.profile.attachments.get("8ce469e228fcdec508209023f525616f1b464597","c9579e96622e96ced35c2198895edaa144bd605c")
# Out:
# CPU times: user 7 ms, sys: 3.87 ms, total: 10.9 ms
# Wall time: 852 ms
# {'code': 200,
#  'message': 'Profile attachment list',
#  'data': [{'type': 'resume',
#    'alt': 'c9579e96622e96ced35c2198895edaa144bd605c',
#    'file_name': 'resume.pdf',
#    'original_file_name': 'resume',
#    'file_size': 128953,
#    'extension': 'pdf',
#    'public_url': 'http://www.hrflow.ai/sf/api/public/profile/attachment?key=Wm11VFRHN0JjeDlJS2xUMmxmTDZUa0E1dmQ3LzdxUFZyM3ArODFESTgrZz0=&type=resume',
#    'timestamp': 1585560863},
#   {'type': 'original',
#    'alt': '0ebc1e37d5e0747f7b82dd8c5a9142a1261ff44b',
#    'file_name': 'original.pdf',
#    'original_file_name': 'original',
#    'file_size': 121410,
#    'extension': 'pdf',
#    'public_url': 'http://www.hrflow.ai/sf/api/public/profile/attachment?key=WSthNTJ4TU9BWmt4M2tzeDdhNm83RXZOVXRPalplR2dnK0dGVVhuWmhXcz0=&type=original',
#    'timestamp': 1585560863}]}

# %% [markdown]
# # GET /profile/parsing

# %%
# %%time
client.profile.parsing.get("8ce469e228fcdec508209023f525616f1b464597","c9579e96622e96ced35c2198895edaa144bd605c")
# Out:
# CPU times: user 11.4 ms, sys: 3.92 ms, total: 15.3 ms
# Wall time: 618 ms
# {'code': 200,
#  'message': 'Profile parsing',
#  'data': {'gender': 'U',
#   'phone': None,
#   'uuid': 'ogWO_HJpEeqgGAJCrBEAAg',
#   'team_id': 'd57948095e4a842ff5436480f382f4b527b94a09',
#   'source_id': '8ce469e228fcdec508209023f525616f1b464597',
#   'profile_id': 'c9579e96622e96ced35c2198895edaa144bd605c',
#   'date_reception': '2020-03-30T09:33:59',
#   'date_creation': '2020-03-30T09:34:21.491602',
#   'name': {'text': 'Rouquier', 'first_name': 'Rouquier', 'last_name': ''},
#   'email': {'text': None},
#   'location': {'text': 'Jean, NV, United States',
#    'geocoder': {'text': 'Jean, NV, United States',
#     'lat': 35.77921,
#     'lng': -115.32509,
#     'gmaps': 'https://www.google.com/maps/place/35.77921,-115.32509',
#     'fields': {'house': None,
#      'category': None,
#      'near': None,
#      'house_number': None,
#      'road': None,
#      'unit': None,
#      'level': None,
#      'staircase': None,
#      'entrance': None,
#      'po_box': None,
#      'postcode': '89019',
#      'suburb': None,
#      'city_district': None,
#      'city': 'Jean',
#      'island': None,
#      'state_district': 'Clark',
#      'state': 'NV',
#      'country_region': None,
#      'country': 'USA',
#      'world_region': None},
#     'is_correct': True},
#    'geopoint': {'lat': 35.77921, 'lon': -115.32509}},
#   'summary': 'Formation et distinctions',
#   'text': {'ar': '',
#    'hy': '',
#    'eu': '',
#    'bn': '',
#    'pt-BR': '',
#    'bg': '',
#    'ca': '',
#    'cjk': '',
#    'cs': '',
#    'da': '',
#    'nl': '',
#    'en': '',
#    'fi': '',
#    'fr': "jean - baptiste rouquier\njean - baptiste . rouquier @ ens - lyon . org\n33 ans\nexpérience professionnelle\n2014 - senior data scientist , dataiku . valorisation des données ( analyse prédictive ) , formation , sup\nport client , documentation , avant - vente . machine learning , python , big data , hadoop , hive .\n2012 – 2014 software engineer , criteo . amélioration de la précision d ' algorithmes d ' apprentissage statis\ntique large échelle , notamment génération , analyse et sélection de nouvelles données . auto\nmatisation du workflow . c # ( . net ) , java , hadoop , git , unit testing , agile\n2011 - 2012 ingénieur - chercheur , eonos investment technologies . apprentissage statistique et finance .\nocaml ( programmation fonctionnelle comme f # ) , python , r , linux\n2009 – 2011 chercheur postdoctorant ( i . e . cdd ) , inria et cnrs , bordeaux et paris .\nmesure , modélisation ( théorique et pratique ) et simulation de systèmes complexes et grands\ngraphes ( e . g . réseaux sociaux , twitter ) . analyse des masses de données et leur dynamique .\nliste de publications : www . rouquier . org / jb / research / publications . php\n2005 - 2008 chercheur doctorant ( informatique ) , école normale supérieure de lyon . dont enseignement .\n2003 – 2007 rédaction , relectures scientifiques et typographiques ,\néditions h & k , annales des concours d ' entrée aux grandes écoles .\ndivers\n– vulgarisateur : notamment science en fête , grand palais , france bleu , articles ,\n– consultant pour veolia : conception d ' un modèle de ville générique , intégré , à grande échelle ,\n– formateur latex ( sessions de 2 ou 3 jours , 8 stagiaires )\ncompétences\ngrâce à mes postes en recherche puis r & d , j ' ai appris à :\n— expliquer clairement des concepts abstraits à des spécialistes / grand public / étudiants , à entre une et\ncent personnes , au travers d ' un exposé formel avec transparents / articles écrits / conversation informelle ,\n– apprendre vite et comprendre en profondeur les sujet théoriques difficiles ,\n– travailler en équipes interdisciplinaires et internationales ( avec des physiciens , mathématiciens , géo\ngraphes , biologistes , développeurs ) , motiver les membres de l ' équipe , organiser un colloque ,\n— travailler de façon automnome en définissant les bonnes questions à résoudre , avec rigueur et créativité .\nthéoriques expert en algorithmes , dont structures de données . expérimenté en probabilités , modélisation ,\ngraphes . culture générale en informatique : théorie des jeux , recherche opérationnelle , optimisation combina\ntoire , logique , paradigmes de programmation , statistiques , etc .\nlangues\nanglais : toeic 990 / 990 .\nallemand : compréhension écrite ( 10 ans de cours , oral réactivable en quelques mois ) .\ndivers\nattestation de formation aux premiers secours . brevet d ' aptitude aux fonctions d ' animateur .\nformation et distinctions\n2011 admis chargé de recherche ( fonctionnaire ) , inra .\n2004 – 2005 master parisien de recherche informatique . 68 / 50 ( 1er aux examens ) , mention très bien .\n2002 – 2004 école normale supérieure , lyon . reçu 3e , également admis à l ' ens ulm et polytechnique .\n2000 – 2002 lycée louis le grand , paris . classes préparatoires .\n2000 baccalauréat . mention très bien , félicitations du jury .\nconcours général mention régionale en mathématiques .\n1989 – 1999 classes à horaires aménagés musique guitare classique ( 11 ans d ' études ) , piano ( 12 ans ) ,\nsolfège ( 11 ans ) , chorale ( 6 ans ) , composition ( 4 ans ) .\nloisirs\n— magie ( président du club local , prestations rémunérées : 12decoeur . fr ) , jonglage et cirque ( 10 ans ) ; -\nmusique ( piano et guitare classiques ) , photographie , cuisine , bricolage et loisirs créatifs ;\n– nouveaux jeux de plateau , souvent de stratégie et réflexion ;\n— sports : course à pied , ski : piste et fond ( skating ) , badminton et squash ; -\ncontributeur à openstreetmap ( plan d ' un village ,  ...
#    'gl': '',
#    'de': '',
#    'el': '',
#    'hi': '',
#    'hu': '',
#    'id': '',
#    'ga': '',
#    'it': '',
#    'lv': '',
#    'lt': '',
#    'no': '',
#    'fa': '',
#    'pt': '',
#    'ro': '',
#    'ru': '',
#    'ku': '',
#    'es': '',
#    'sv': '',
#    'tr': '',
#    'th': ''},
#   'experiences': [{'id': '215ae1b5ef95d0df91c6be296175272abbeec1ed',
#     'start_date': {'text': None, 'date': None},
#     'end_date': {'text': '2014', 'date': '2014-01-01T00:00:00'},
#     'location': {'text': None,
#      'geocoder': {'text': None,
#       'lat': None,
#       'lng': None,
#       'gmaps': None,
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': None,
#        'suburb': None,
#        'city_district': None,
#        'city': None,
#        'island': None,
#        'state_district': None,
#        'state': None,
#        'country_region': None,
#        'country': None,
#        'world_region': None},
#       'is_correct': None},
#      'geopoint': {'lat': None, 'lon': None}},
#     'title': '',
#     'description': '  - Senior Data Scientist , Dataiku . Valorisation des données ( analyse prédictive ) , formation , sup\nport client , documentation , avant - vente . Machine Learning , Python , Big data , Hadoop , Hive .',
#     'company': None},
#    {'id': '6f68ba93519c9ad75382858bc85ab8f367741744',
#     'start_date': {'text': '2012', 'date': '2012-01-01T00:00:00'},
#     'end_date': {'text': '2014', 'date': '2014-01-01T00:00:00'},
#     'location': {'text': None,
#      'geocoder': {'text': None,
#       'lat': None,
#       'lng': None,
#       'gmaps': None,
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': None,
#        'suburb': None,
#        'city_district': None,
#        'city': None,
#        'island': None,
#        'state_district': None,
#        'state': None,
#        'country_region': None,
#        'country': None,
#        'world_region': None},
#       'is_correct': None},
#      'geopoint': {'lat': None, 'lon': None}},
#     'title': 'Software engineer',
#     'description': "  –       Amélioration de la précision d ' algorithmes d ' apprentissage statis\ntique large échelle , notamment génération , analyse et sélection de nouvelles données . Auto\nmatisation du workflow . C # ( . Net ) , Java , Hadoop , Git , Unit testing , Agile",
#     'company': 'Criteo'},
#    {'id': '1b09b2f314a6a902d822dac6cc67dd4b1a5c1c2c',
#     'start_date': {'text': '2011', 'date': '2011-01-01T00:00:00'},
#     'end_date': {'text': '- 2012', 'date': '2012-01-01T00:00:00'},
#     'location': {'text': None,
#      'geocoder': {'text': None,
#       'lat': None,
#       'lng': None,
#       'gmaps': None,
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': None,
#        'suburb': None,
#        'city_district': None,
#        'city': None,
#        'island': None,
#        'state_district': None,
#        'state': None,
#        'country_region': None,
#        'country': None,
#        'world_region': None},
#       'is_correct': None},
#      'geopoint': {'lat': None, 'lon': None}},
#     'title': 'Ingénieur - chercheur',
#     'description': '        Apprentissage statistique et finance .\nOCaml ( programmation fonctionnelle comme F # ) , Python , R , Linux',
#     'company': 'Eonos Investment Technologies'},
#    {'id': '09c07caaf49e2d42eda882839c3d716025e2121f',
#     'start_date': {'text': '2009', 'date': '2009-01-01T00:00:00'},
#     'end_date': {'text': '2011', 'date': '2011-01-01T00:00:00'},
#     'location': {'text': 'Passage de Paris, 33300 Bordeaux, France',
#      'geocoder': {'text': 'Passage de Paris, 33300 Bordeaux, France',
#       'lat': 44.85565,
#       'lng': -0.57409,
#       'gmaps': 'https://www.google.com/maps/place/44.85565,-0.57409',
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': 'Passage de Paris',
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': '33300',
#        'suburb': 'Bordeaux Maritime',
#        'city_district': 'Bordeaux Maritime',
#        'city': 'Bordeaux',
#        'island': None,
#        'state_district': 'Gironde',
#        'state': 'Nouvelle-Aquitaine',
#        'country_region': None,
#        'country': 'FRA',
#        'world_region': None},
#       'is_correct': True},
#      'geopoint': {'lat': 44.85565, 'lon': -0.57409}},
#     'title': 'Chercheur postdoctorant i. e',
#     'description': '  –     CDD ) , INRIA et CNRS , \nMesure , modélisation ( théorique et pratique ) et simulation de systèmes complexes et grands\ngraphes ( e . g . réseaux sociaux , Twitter ) . Analyse des masses de données et leur dynamique .\nListe de publications : www . rouquier . org / jb / research / publications . php',
#     'company': 'INRIA CNRS'},
#    {'id': '8b72db2344de79546a2295fda89ef99283e67317',
#     'start_date': {'text': '2005', 'date': '2005-01-01T00:00:00'},
#     'end_date': {'text': '- 2008', 'date': '2008-01-01T00:00:00'},
#     'location': {'text': None,
#      'geocoder': {'text': None,
#       'lat': None,
#       'lng': None,
#       'gmaps': None,
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': None,
#        'suburb': None,
#        'city_district': None,
#        'city': None,
#        'island': None,
#        'state_district': None,
#        'state': None,
#        'country_region': None,
#        'country': None,
#        'world_region': None},
#       'is_correct': None},
#      'geopoint': {'lat': None, 'lon': None}},
#     'title': 'Chercheur doctorant informatique',
#     'description': "        Dont enseignement .\n2003 – 2007 Rédaction , relectures scientifiques et typographiques ,\nÉditions H & K , Annales des concours d ' entrée aux grandes écoles .",
#     'company': 'École Normale Supérieure de Lyon'},
#    {'id': '8d539cbed4c2e0ad22fc7584d6c04116ae94ae57',
#     'start_date': {'text': None, 'date': None},
#     'end_date': {'text': None, 'date': None},
#     'location': {'text': "Le Grand Palais, L'Isle-sur-la-Sorgue, Provence-Alpes-Cote d'Azur, France",
#      'geocoder': {'text': "Le Grand Palais, L'Isle-sur-la-Sorgue, Provence-Alpes-Cote d'Azur, France",
#       'lat': 43.88248,
#       'lng': 5.07193,
#       'gmaps': 'https://www.google.com/maps/place/43.88248,5.07193',
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': '84800',
#        'suburb': 'Le Grand Palais',
#        'city_district': 'Le Grand Palais',
#        'city': "L'Isle-sur-la-Sorgue",
#        'island': None,
#        'state_district': 'Vaucluse',
#        'state': "Provence-Alpes-Cote d'Azur",
#        'country_region': None,
#        'country': 'FRA',
#        'world_region': None},
#       'is_correct': True},
#      'geopoint': {'lat': 43.88248, 'lon': 5.07193}},
#     'title': 'Consultant',
#     'description': "– Vulgarisateur : notamment Science en fête ,  Bleu , articles ,\n–   pour Veolia : conception d ' un modèle de ville générique , intégré , à grande échelle ,\n– Formateur LATEX ( sessions de 2 ou 3 jours , 8 stagiaires )",
#     'company': None}],
#   'experiences_duration': 8.002739726027396,
#   'educations': [{'id': '4a779e9394bb19f1d14d2db5f9bc6dc4a91cf763',
#     'start_date': {'text': '2004 2005', 'date': '2004-05-01T00:00:00'},
#     'end_date': {'text': '2011', 'date': '2011-05-01T00:00:00'},
#     'location': {'text': None,
#      'geocoder': {'text': None,
#       'lat': None,
#       'lng': None,
#       'gmaps': None,
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': None,
#        'suburb': None,
#        'city_district': None,
#        'city': None,
#        'island': None,
#        'state_district': None,
#        'state': None,
#        'country_region': None,
#        'country': None,
#        'world_region': None},
#       'is_correct': None},
#      'geopoint': {'lat': None, 'lon': None}},
#     'title': 'Admis Chargé de recherche fonctionnaire',
#     'description': '      .\n2004 – 2005 Master Parisien de Recherche Informatique . 68 / 50 ( 1er aux examens ) , mention Très Bien .',
#     'school': 'INRA'},
#    {'id': '6e4297db9242eb1dc2ba6473250e5b595c323b2e',
#     'start_date': {'text': '2002', 'date': '2002-01-01T00:00:00'},
#     'end_date': {'text': '– 2004', 'date': '2004-01-01T00:00:00'},
#     'location': {'text': 'Lyon, Auvergne-Rhone-Alpes, France',
#      'geocoder': {'text': 'Lyon, Auvergne-Rhone-Alpes, France',
#       'lat': 45.7592,
#       'lng': 4.82967,
#       'gmaps': 'https://www.google.com/maps/place/45.7592,4.82967',
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': '69002',
#        'suburb': None,
#        'city_district': None,
#        'city': 'Lyon',
#        'island': None,
#        'state_district': 'Rhône',
#        'state': 'Auvergne-Rhone-Alpes',
#        'country_region': None,
#        'country': 'FRA',
#        'world_region': None},
#       'is_correct': True},
#      'geopoint': {'lat': 45.7592, 'lon': 4.82967}},
#     'title': 'Reçu 3e, également admis à',
#     'description': "         l ' ENS Ulm et Polytechnique .",
#     'school': 'École Normale Supérieure'},
#    {'id': 'c29eaf69eb61bd85e37dfc4b0c744a721f97d463',
#     'start_date': {'text': '2000', 'date': '2000-01-01T00:00:00'},
#     'end_date': {'text': '– 2002', 'date': '2002-01-01T00:00:00'},
#     'location': {'text': 'Paris, Ile-de-France, France',
#      'geocoder': {'text': 'Paris, Ile-de-France, France',
#       'lat': 48.85718,
#       'lng': 2.34141,
#       'gmaps': 'https://www.google.com/maps/place/48.85718,2.34141',
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': '75001',
#        'suburb': None,
#        'city_district': None,
#        'city': 'Paris',
#        'island': None,
#        'state_district': 'Paris',
#        'state': 'Ile-de-France',
#        'country_region': None,
#        'country': 'FRA',
#        'world_region': None},
#       'is_correct': True},
#      'geopoint': {'lat': 48.85718, 'lon': 2.34141}},
#     'title': 'Classes préparatoires',
#     'description': '',
#     'school': 'Lycée Louis le Grand'},
#    {'id': 'a20f62468115d4dd8bbbec8a7d34aab7c8ef09ad',
#     'start_date': {'text': '2000', 'date': '2000-01-01T00:00:00'},
#     'end_date': {'text': None, 'date': None},
#     'location': {'text': None,
#      'geocoder': {'text': None,
#       'lat': None,
#       'lng': None,
#       'gmaps': None,
#       'fields': {'house': None,
#        'category': None,
#        'near': None,
#        'house_number': None,
#        'road': None,
#        'unit': None,
#        'level': None,
#        'staircase': None,
#        'entrance': None,
#        'po_box': None,
#        'postcode': None,
#        'suburb': None,
#        'city_district': None,
#        'city': None,
#        'island': None,
#        'state_district': None,
#        'state': None,
#        'country_region': None,
#        'country': None,
#        'world_region': None},
#       'is_correct': None},
#      'geopoint': {'lat': None, 'lon': None}},
#     'title': 'Baccalauréat',
#     'description': '    Mention Très Bien , félicitations du jury .\nConcours général mention régionale en mathématiques .',
#     'school': None}],
#   'educations_duration': 11.005479452054795,
#   'skills': [{'name': 'R & D',
#     'value': None,
#     'type': None,
#     'is_predicted': False},
#    {'name': 'recherche', 'value': None, 'type': None, 'is_predicted': False},
#    {'name': 'Anglais', 'value': None, 'type': None, 'is_predicted': False},
#    {'name': 'Allemand', 'value': None, 'type': None, 'is_predicted': False}],
#   'languages': [],
#   'interests': [{'name': "squash ; -\nContributeur à OpenStreetMap ( plan d ' un village , outil statistique",
#     'value': None},
#    {'name': 'Guitare classique', 'value': None},
#    {'name': 'composition', 'value': None},
#    {'name': 'Sports', 'value': None},
#    {'name': 'jonglage', 'value': None},
#    {'name': '; -\nMusique ( piano', 'value': None},
#    {'name': 'guitare', 'value': None},
#    {'name': 'pied , ski', 'value': None},
#    {'name': 'photographie , cuisine , bricolage', 'value': None},
#    {'name': 'Magie', 'value': None},
#    {'name': 'piano', 'value': None},
#    {'name': 'chorale', 'value': None},
#    {'name': 'fond ( skating ) , badminton', 'value': None},
#    {'name': 'musique', 'value': None},
#    {'name': 'solfège', 'value': None},
#    {'name': 'stratégie', 'value': None}],
#   'tags': [{'name': 'email', 'value': 'test@test.com'},
#    {'name': 'referrer', 'value': None}],
#   'labels': [],
#   'urls': {'from_resume': [], 'picture': None}}}

# %% [markdown]
# # GET /profile/revealing

# %% [markdown]
# # GET /profile/searching

# %%
# %%time

client.profile.search(source_ids=["8ce469e228fcdec508209023f525616f1b464597"], limit=1)
# Out:
# CPU times: user 9.73 ms, sys: 3 ms, total: 12.7 ms
# Wall time: 1.65 s
# {'code': 200,
#  'message': 'Profiles list',
#  'page': 1,
#  'max_page': 3,
#  'count': 1,
#  'total': 3,
#  'data': {'profiles': [{'date_creation': '2020-03-31T12:04:52.858408',
#     'date_reception': '2020-03-31T12:04:42',
#     'educations': [{'description': 'Etude des mathematique',
#       'end_date': {'date': None, 'text': '12550'},
#       'id': 'b03c71f748a048f96bcda33397457a81d8bf1301',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'school': 'Université de Hélicon',
#       'start_date': {'date': None, 'text': '12540'},
#       'title': "Diplome d'ingénieur mathematicien"}],
#     'educations_duration': 0,
#     'email': {'text': 'harisledon@trantor.trt'},
#     'experiences': [{'company': 'Departement de la psychohistoire',
#       'description': 'Developping psychohistoire.',
#       'end_date': {'date': None, 'text': ''},
#       'id': '7161ef290537610d6f46b2f6468d93286bdd361b',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': None, 'text': '15/02/12600'},
#       'title': 'Lead'}],
#     'experiences_duration': 0,
#     'interests': [{'name': 'football', 'value': None}],
#     'location': {'geocoder': {'fields': {'category': None,
#        'city': None,
#        'city_district': None,
#        'country': None,
#        'country_region': None,
#        'entrance': None,
#        'house': None,
#        'house_number': None,
#        'island': None,
#        'level': None,
#        'near': None,
#        'po_box': None,
#        'postcode': None,
#        'road': None,
#        'staircase': None,
#        'state': None,
#        'state_district': None,
#        'suburb': None,
#        'unit': None,
#        'world_region': None},
#       'gmaps': None,
#       'is_correct': None,
#       'lat': None,
#       'lng': None,
#       'text': None},
#      'geopoint': {'lat': None, 'lon': None},
#      'text': None},
#     'name': {'first_name': None, 'last_name': None, 'text': 'Hari Seldon'},
#     'profile_id': '597b16789ba389cbc67a638d808b8f40220ba988',
#     'skills': [{'is_predicted': False,
#       'name': 'manual skill',
#       'type': None,
#       'value': None},
#      {'is_predicted': False,
#       'name': 'Creative spirit',
#       'type': None,
#       'value': None},
#      {'is_predicted': False,
#       'name': 'Writing skills',
#       'type': None,
#       'value': None},
#      {'is_predicted': False,
#       'name': 'Communication',
#       'type': None,
#       'value': None},
#      {'is_predicted': False,
#       'name': 'Project management',
#       'type': None,
#       'value': None},
#      {'is_predicted': False, 'name': 'French', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'German', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Korean', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'English', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Esquive', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Research', 'type': None, 'value': None},
#      {'is_predicted': False,
#       'name': 'Mathematique',
#       'type': None,
#       'value': None}],
#     'source_id': '8ce469e228fcdec508209023f525616f1b464597',
#     'summary': 'test summary',
#     'tags': [{'name': 'email', 'value': 'test@test.com'},
#      {'name': 'referrer', 'value': None}],
#     'team_id': 'd57948095e4a842ff5436480f382f4b527b94a09',
#     'text': {'ar': '',
#      'bg': '',
#      'bn': '',
#      'ca': '',
#      'cjk': '',
#      'cs': '',
#      'da': '',
#      'de': '',
#      'el': '',
#      'en': '',
#      'es': '',
#      'eu': '',
#      'fa': '',
#      'fi': '',
#      'fr': "hari seldon harisledon@trantor.trt  test summary  15/02/12600  lead departement de la psychohistoire  developping psychohistoire. 12540 12550 diplome d'ingénieur mathematicien  université de hélicon etude des mathematique football",
#      'ga': '',
#      'gl': '',
#      'hi': '',
#      'hu': '',
#      'hy': '',
#      'id': '',
#      'it': '',
#      'ku': '',
#      'lt': '',
#      'lv': '',
#      'nl': '',
#      'no': '',
#      'pt': '',
#      'pt-BR': '',
#      'ro': '',
#      'ru': '',
#      'sv': '',
#      'th': '',
#      'tr': ''},
#     'urls': {'from_resume': [], 'picture': None},
#     'uuid': '1DiimnNHEeqCnwJCrBEAAg'}],
#   'predictions': []}}

# %% [markdown]
# # GET /profiles/scoring

# %%
client.profile.scoring.search(source_ids=["8ce469e228fcdec508209023f525616f1b464597"], job_id="a25bc879e774cc508706f6f4ddd8cce036689f3a", stage="new")
# Out:
# <Response [200]>
# {'code': 200,
#  'message': 'Profiles list',
#  'page': 1,
#  'max_page': 1,
#  'count': 3,
#  'total': 3,
#  'data': {'profiles': [{'date_creation': '2020-03-31T12:04:52.858408',
#     'date_reception': '2020-03-31T12:04:42',
#     'educations': [{'description': 'Etude des mathematique',
#       'end_date': {'date': None, 'text': '12550'},
#       'id': 'b03c71f748a048f96bcda33397457a81d8bf1301',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'school': 'Université de Hélicon',
#       'start_date': {'date': None, 'text': '12540'},
#       'title': "Diplome d'ingénieur mathematicien"}],
#     'educations_duration': 0,
#     'email': {'text': 'harisledon@trantor.trt'},
#     'experiences': [{'company': 'Departement de la psychohistoire',
#       'description': 'Developping psychohistoire.',
#       'end_date': {'date': None, 'text': ''},
#       'id': '7161ef290537610d6f46b2f6468d93286bdd361b',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': None, 'text': '15/02/12600'},
#       'title': 'Lead'}],
#     'experiences_duration': 0,
#     'interests': [{'name': 'football', 'value': None}],
#     'location': {'geocoder': {'fields': {'category': None,
#        'city': None,
#        'city_district': None,
#        'country': None,
#        'country_region': None,
#        'entrance': None,
#        'house': None,
#        'house_number': None,
#        'island': None,
#        'level': None,
#        'near': None,
#        'po_box': None,
#        'postcode': None,
#        'road': None,
#        'staircase': None,
#        'state': None,
#        'state_district': None,
#        'suburb': None,
#        'unit': None,
#        'world_region': None},
#       'gmaps': None,
#       'is_correct': None,
#       'lat': None,
#       'lng': None,
#       'text': None},
#      'geopoint': {'lat': None, 'lon': None},
#      'text': None},
#     'name': {'first_name': None, 'last_name': None, 'text': 'Hari Seldon'},
#     'profile_id': '597b16789ba389cbc67a638d808b8f40220ba988',
#     'skills': [{'is_predicted': False,
#       'name': 'manual skill',
#       'type': None,
#       'value': None},
#      {'is_predicted': False,
#       'name': 'Creative spirit',
#       'type': None,
#       'value': None},
#      {'is_predicted': False,
#       'name': 'Writing skills',
#       'type': None,
#       'value': None},
#      {'is_predicted': False,
#       'name': 'Communication',
#       'type': None,
#       'value': None},
#      {'is_predicted': False,
#       'name': 'Project management',
#       'type': None,
#       'value': None},
#      {'is_predicted': False, 'name': 'French', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'German', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Korean', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'English', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Esquive', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Research', 'type': None, 'value': None},
#      {'is_predicted': False,
#       'name': 'Mathematique',
#       'type': None,
#       'value': None}],
#     'source_id': '8ce469e228fcdec508209023f525616f1b464597',
#     'summary': 'test summary',
#     'tags': [{'name': 'email', 'value': 'test@test.com'},
#      {'name': 'referrer', 'value': None}],
#     'team_id': 'd57948095e4a842ff5436480f382f4b527b94a09',
#     'text': {'ar': '',
#      'bg': '',
#      'bn': '',
#      'ca': '',
#      'cjk': '',
#      'cs': '',
#      'da': '',
#      'de': '',
#      'el': '',
#      'en': '',
#      'es': '',
#      'eu': '',
#      'fa': '',
#      'fi': '',
#      'fr': "hari seldon harisledon@trantor.trt  test summary  15/02/12600  lead departement de la psychohistoire  developping psychohistoire. 12540 12550 diplome d'ingénieur mathematicien  université de hélicon etude des mathematique football",
#      'ga': '',
#      'gl': '',
#      'hi': '',
#      'hu': '',
#      'hy': '',
#      'id': '',
#      'it': '',
#      'ku': '',
#      'lt': '',
#      'lv': '',
#      'nl': '',
#      'no': '',
#      'pt': '',
#      'pt-BR': '',
#      'ro': '',
#      'ru': '',
#      'sv': '',
#      'th': '',
#      'tr': ''},
#     'urls': {'from_resume': [], 'picture': None},
#     'uuid': '1DiimnNHEeqCnwJCrBEAAg'},
#    {'date_creation': '2020-03-30T09:34:21.491602',
#     'date_reception': '2020-03-30T09:33:59',
#     'educations': [{'description': '      .\n2004 – 2005 Master Parisien de Recherche Informatique . 68 / 50 ( 1er aux examens ) , mention Très Bien .',
#       'end_date': {'date': '2011-05-01T00:00:00', 'text': '2011'},
#       'id': '4a779e9394bb19f1d14d2db5f9bc6dc4a91cf763',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'school': 'INRA',
#       'start_date': {'date': '2004-05-01T00:00:00', 'text': '2004 2005'},
#       'title': 'Admis Chargé de recherche fonctionnaire'},
#      {'description': "         l ' ENS Ulm et Polytechnique .",
#       'end_date': {'date': '2004-01-01T00:00:00', 'text': '– 2004'},
#       'id': '6e4297db9242eb1dc2ba6473250e5b595c323b2e',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': 'Lyon',
#          'city_district': None,
#          'country': 'FRA',
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': '69002',
#          'road': None,
#          'staircase': None,
#          'state': 'Auvergne-Rhone-Alpes',
#          'state_district': 'Rhône',
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': 'https://www.google.com/maps/place/45.7592,4.82967',
#         'is_correct': True,
#         'lat': 45.7592,
#         'lng': 4.82967,
#         'text': 'Lyon, Auvergne-Rhone-Alpes, France'},
#        'geopoint': {'lat': 45.7592, 'lon': 4.82967},
#        'text': 'Lyon, Auvergne-Rhone-Alpes, France'},
#       'school': 'École Normale Supérieure',
#       'start_date': {'date': '2002-01-01T00:00:00', 'text': '2002'},
#       'title': 'Reçu 3e, également admis à'},
#      {'description': '',
#       'end_date': {'date': '2002-01-01T00:00:00', 'text': '– 2002'},
#       'id': 'c29eaf69eb61bd85e37dfc4b0c744a721f97d463',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': 'Paris',
#          'city_district': None,
#          'country': 'FRA',
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': '75001',
#          'road': None,
#          'staircase': None,
#          'state': 'Ile-de-France',
#          'state_district': 'Paris',
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': 'https://www.google.com/maps/place/48.85718,2.34141',
#         'is_correct': True,
#         'lat': 48.85718,
#         'lng': 2.34141,
#         'text': 'Paris, Ile-de-France, France'},
#        'geopoint': {'lat': 48.85718, 'lon': 2.34141},
#        'text': 'Paris, Ile-de-France, France'},
#       'school': 'Lycée Louis le Grand',
#       'start_date': {'date': '2000-01-01T00:00:00', 'text': '2000'},
#       'title': 'Classes préparatoires'},
#      {'description': '    Mention Très Bien , félicitations du jury .\nConcours général mention régionale en mathématiques .',
#       'end_date': {'date': None, 'text': None},
#       'id': 'a20f62468115d4dd8bbbec8a7d34aab7c8ef09ad',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'school': None,
#       'start_date': {'date': '2000-01-01T00:00:00', 'text': '2000'},
#       'title': 'Baccalauréat'}],
#     'educations_duration': 11.005479452054795,
#     'email': {'text': None},
#     'experiences': [{'company': None,
#       'description': '  - Senior Data Scientist , Dataiku . Valorisation des données ( analyse prédictive ) , formation , sup\nport client , documentation , avant - vente . Machine Learning , Python , Big data , Hadoop , Hive .',
#       'end_date': {'date': '2014-01-01T00:00:00', 'text': '2014'},
#       'id': '215ae1b5ef95d0df91c6be296175272abbeec1ed',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': None, 'text': None},
#       'title': ''},
#      {'company': 'Criteo',
#       'description': "  –       Amélioration de la précision d ' algorithmes d ' apprentissage statis\ntique large échelle , notamment génération , analyse et sélection de nouvelles données . Auto\nmatisation du workflow . C # ( . Net ) , Java , Hadoop , Git , Unit testing , Agile",
#       'end_date': {'date': '2014-01-01T00:00:00', 'text': '2014'},
#       'id': '6f68ba93519c9ad75382858bc85ab8f367741744',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': '2012-01-01T00:00:00', 'text': '2012'},
#       'title': 'Software engineer'},
#      {'company': 'Eonos Investment Technologies',
#       'description': '        Apprentissage statistique et finance .\nOCaml ( programmation fonctionnelle comme F # ) , Python , R , Linux',
#       'end_date': {'date': '2012-01-01T00:00:00', 'text': '- 2012'},
#       'id': '1b09b2f314a6a902d822dac6cc67dd4b1a5c1c2c',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': '2011-01-01T00:00:00', 'text': '2011'},
#       'title': 'Ingénieur - chercheur'},
#      {'company': 'INRIA CNRS',
#       'description': '  –     CDD ) , INRIA et CNRS , \nMesure , modélisation ( théorique et pratique ) et simulation de systèmes complexes et grands\ngraphes ( e . g . réseaux sociaux , Twitter ) . Analyse des masses de données et leur dynamique .\nListe de publications : www . rouquier . org / jb / research / publications . php',
#       'end_date': {'date': '2011-01-01T00:00:00', 'text': '2011'},
#       'id': '09c07caaf49e2d42eda882839c3d716025e2121f',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': 'Bordeaux',
#          'city_district': 'Bordeaux Maritime',
#          'country': 'FRA',
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': '33300',
#          'road': 'Passage de Paris',
#          'staircase': None,
#          'state': 'Nouvelle-Aquitaine',
#          'state_district': 'Gironde',
#          'suburb': 'Bordeaux Maritime',
#          'unit': None,
#          'world_region': None},
#         'gmaps': 'https://www.google.com/maps/place/44.85565,-0.57409',
#         'is_correct': True,
#         'lat': 44.85565,
#         'lng': -0.57409,
#         'text': 'Passage de Paris, 33300 Bordeaux, France'},
#        'geopoint': {'lat': 44.85565, 'lon': -0.57409},
#        'text': 'Passage de Paris, 33300 Bordeaux, France'},
#       'start_date': {'date': '2009-01-01T00:00:00', 'text': '2009'},
#       'title': 'Chercheur postdoctorant i. e'},
#      {'company': 'École Normale Supérieure de Lyon',
#       'description': "        Dont enseignement .\n2003 – 2007 Rédaction , relectures scientifiques et typographiques ,\nÉditions H & K , Annales des concours d ' entrée aux grandes écoles .",
#       'end_date': {'date': '2008-01-01T00:00:00', 'text': '- 2008'},
#       'id': '8b72db2344de79546a2295fda89ef99283e67317',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': '2005-01-01T00:00:00', 'text': '2005'},
#       'title': 'Chercheur doctorant informatique'},
#      {'company': None,
#       'description': "– Vulgarisateur : notamment Science en fête ,  Bleu , articles ,\n–   pour Veolia : conception d ' un modèle de ville générique , intégré , à grande échelle ,\n– Formateur LATEX ( sessions de 2 ou 3 jours , 8 stagiaires )",
#       'end_date': {'date': None, 'text': None},
#       'id': '8d539cbed4c2e0ad22fc7584d6c04116ae94ae57',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': "L'Isle-sur-la-Sorgue",
#          'city_district': 'Le Grand Palais',
#          'country': 'FRA',
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': '84800',
#          'road': None,
#          'staircase': None,
#          'state': "Provence-Alpes-Cote d'Azur",
#          'state_district': 'Vaucluse',
#          'suburb': 'Le Grand Palais',
#          'unit': None,
#          'world_region': None},
#         'gmaps': 'https://www.google.com/maps/place/43.88248,5.07193',
#         'is_correct': True,
#         'lat': 43.88248,
#         'lng': 5.07193,
#         'text': "Le Grand Palais, L'Isle-sur-la-Sorgue, Provence-Alpes-Cote d'Azur, France"},
#        'geopoint': {'lat': 43.88248, 'lon': 5.07193},
#        'text': "Le Grand Palais, L'Isle-sur-la-Sorgue, Provence-Alpes-Cote d'Azur, France"},
#       'start_date': {'date': None, 'text': None},
#       'title': 'Consultant'}],
#     'experiences_duration': 8.002739726027396,
#     'interests': [{'name': "squash ; -\nContributeur à OpenStreetMap ( plan d ' un village , outil statistique",
#       'value': None},
#      {'name': 'Guitare classique', 'value': None},
#      {'name': 'composition', 'value': None},
#      {'name': 'Sports', 'value': None},
#      {'name': 'jonglage', 'value': None},
#      {'name': '; -\nMusique ( piano', 'value': None},
#      {'name': 'guitare', 'value': None},
#      {'name': 'pied , ski', 'value': None},
#      {'name': 'photographie , cuisine , bricolage', 'value': None},
#      {'name': 'Magie', 'value': None},
#      {'name': 'piano', 'value': None},
#      {'name': 'chorale', 'value': None},
#      {'name': 'fond ( skating ) , badminton', 'value': None},
#      {'name': 'musique', 'value': None},
#      {'name': 'solfège', 'value': None},
#      {'name': 'stratégie', 'value': None}],
#     'location': {'geocoder': {'fields': {'category': None,
#        'city': 'Jean',
#        'city_district': None,
#        'country': 'USA',
#        'country_region': None,
#        'entrance': None,
#        'house': None,
#        'house_number': None,
#        'island': None,
#        'level': None,
#        'near': None,
#        'po_box': None,
#        'postcode': '89019',
#        'road': None,
#        'staircase': None,
#        'state': 'NV',
#        'state_district': 'Clark',
#        'suburb': None,
#        'unit': None,
#        'world_region': None},
#       'gmaps': 'https://www.google.com/maps/place/35.77921,-115.32509',
#       'is_correct': True,
#       'lat': 35.77921,
#       'lng': -115.32509,
#       'text': 'Jean, NV, United States'},
#      'geopoint': {'lat': 35.77921, 'lon': -115.32509},
#      'text': 'Jean, NV, United States'},
#     'name': {'first_name': 'Rouquier', 'last_name': '', 'text': 'Rouquier'},
#     'profile_id': 'c9579e96622e96ced35c2198895edaa144bd605c',
#     'skills': [{'is_predicted': False,
#       'name': 'R & D',
#       'type': None,
#       'value': None},
#      {'is_predicted': False, 'name': 'recherche', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Anglais', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Allemand', 'type': None, 'value': None}],
#     'source_id': '8ce469e228fcdec508209023f525616f1b464597',
#     'summary': 'Formation et distinctions',
#     'tags': [{'name': 'email', 'value': 'test@test.com'},
#      {'name': 'referrer', 'value': None}],
#     'team_id': 'd57948095e4a842ff5436480f382f4b527b94a09',
#     'text': {'ar': '',
#      'bg': '',
#      'bn': '',
#      'ca': '',
#      'cjk': '',
#      'cs': '',
#      'da': '',
#      'de': '',
#      'el': '',
#      'en': '',
#      'es': '',
#      'eu': '',
#      'fa': '',
#      'fi': '',
#      'fr': "jean - baptiste rouquier\njean - baptiste . rouquier @ ens - lyon . org\n33 ans\nexpérience professionnelle\n2014 - senior data scientist , dataiku . valorisation des données ( analyse prédictive ) , formation , sup\nport client , documentation , avant - vente . machine learning , python , big data , hadoop , hive .\n2012 – 2014 software engineer , criteo . amélioration de la précision d ' algorithmes d ' apprentissage statis\ntique large échelle , notamment génération , analyse et sélection de nouvelles données . auto\nmatisation du workflow . c # ( . net ) , java , hadoop , git , unit testing , agile\n2011 - 2012 ingénieur - chercheur , eonos investment technologies . apprentissage statistique et finance .\nocaml ( programmation fonctionnelle comme f # ) , python , r , linux\n2009 – 2011 chercheur postdoctorant ( i . e . cdd ) , inria et cnrs , bordeaux et paris .\nmesure , modélisation ( théorique et pratique ) et simulation de systèmes complexes et grands\ngraphes ( e . g . réseaux sociaux , twitter ) . analyse des masses de données et leur dynamique .\nliste de publications : www . rouquier . org / jb / research / publications . php\n2005 - 2008 chercheur doctorant ( informatique ) , école normale supérieure de lyon . dont enseignement .\n2003 – 2007 rédaction , relectures scientifiques et typographiques ,\néditions h & k , annales des concours d ' entrée aux grandes écoles .\ndivers\n– vulgarisateur : notamment science en fête , grand palais , france bleu , articles ,\n– consultant pour veolia : conception d ' un modèle de ville générique , intégré , à grande échelle ,\n– formateur latex ( sessions de 2 ou 3 jours , 8 stagiaires )\ncompétences\ngrâce à mes postes en recherche puis r & d , j ' ai appris à :\n— expliquer clairement des concepts abstraits à des spécialistes / grand public / étudiants , à entre une et\ncent personnes , au travers d ' un exposé formel avec transparents / articles écrits / conversation informelle ,\n– apprendre vite et comprendre en profondeur les sujet théoriques difficiles ,\n– travailler en équipes interdisciplinaires et internationales ( avec des physiciens , mathématiciens , géo\ngraphes , biologistes , développeurs ) , motiver les membres de l ' équipe , organiser un colloque ,\n— travailler de façon automnome en définissant les bonnes questions à résoudre , avec rigueur et créativité .\nthéoriques expert en algorithmes , dont structures de données . expérimenté en probabilités , modélisation ,\ngraphes . culture générale en informatique : théorie des jeux , recherche opérationnelle , optimisation combina\ntoire , logique , paradigmes de programmation , statistiques , etc .\nlangues\nanglais : toeic 990 / 990 .\nallemand : compréhension écrite ( 10 ans de cours , oral réactivable en quelques mois ) .\ndivers\nattestation de formation aux premiers secours . brevet d ' aptitude aux fonctions d ' animateur .\nformation et distinctions\n2011 admis chargé de recherche ( fonctionnaire ) , inra .\n2004 – 2005 master parisien de recherche informatique . 68 / 50 ( 1er aux examens ) , mention très bien .\n2002 – 2004 école normale supérieure , lyon . reçu 3e , également admis à l ' ens ulm et polytechnique .\n2000 – 2002 lycée louis le grand , paris . classes préparatoires .\n2000 baccalauréat . mention très bien , félicitations du jury .\nconcours général mention régionale en mathématiques .\n1989 – 1999 classes à horaires aménagés musique guitare classique ( 11 ans d ' études ) , piano ( 12 ans ) ,\nsolfège ( 11 ans ) , chorale ( 6 ans ) , composition ( 4 ans ) .\nloisirs\n— magie ( président du club local , prestations rémunérées : 12decoeur . fr ) , jonglage et cirque ( 10 ans ) ; -\nmusique ( piano et guitare classiques ) , photographie , cuisine , bricolage et loisirs créatifs ;\n– nouveaux jeux de plateau , souvent de stratégie et réflexion ;\n— sports : course à pied , ski : piste et fond ( skating ) , badminton et squash ; -\ncontributeur à openstreetmap ( plan d ' un village  ...
#      'ga': '',
#      'gl': '',
#      'hi': '',
#      'hu': '',
#      'hy': '',
#      'id': '',
#      'it': '',
#      'ku': '',
#      'lt': '',
#      'lv': '',
#      'nl': '',
#      'no': '',
#      'pt': '',
#      'pt-BR': '',
#      'ro': '',
#      'ru': '',
#      'sv': '',
#      'th': '',
#      'tr': ''},
#     'urls': {'from_resume': [], 'picture': None},
#     'uuid': 'ogWO_HJpEeqgGAJCrBEAAg'},
#    {'date_creation': '2020-03-30T09:31:52.983457',
#     'date_reception': '2020-03-30T09:31:26',
#     'educations': [{'description': '      .\n2004 – 2005 Master Parisien de Recherche Informatique . 68 / 50 ( 1er aux examens ) , mention Très Bien .',
#       'end_date': {'date': '2011-05-01T00:00:00', 'text': '2011'},
#       'id': '4a779e9394bb19f1d14d2db5f9bc6dc4a91cf763',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'school': 'INRA',
#       'start_date': {'date': '2004-05-01T00:00:00', 'text': '2004 2005'},
#       'title': 'Admis Chargé de recherche fonctionnaire'},
#      {'description': "         l ' ENS Ulm et Polytechnique .",
#       'end_date': {'date': '2004-01-01T00:00:00', 'text': '– 2004'},
#       'id': '6e4297db9242eb1dc2ba6473250e5b595c323b2e',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': 'Lyon',
#          'city_district': None,
#          'country': 'FRA',
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': '69002',
#          'road': None,
#          'staircase': None,
#          'state': 'Auvergne-Rhone-Alpes',
#          'state_district': 'Rhône',
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': 'https://www.google.com/maps/place/45.7592,4.82967',
#         'is_correct': True,
#         'lat': 45.7592,
#         'lng': 4.82967,
#         'text': 'Lyon, Auvergne-Rhone-Alpes, France'},
#        'geopoint': {'lat': 45.7592, 'lon': 4.82967},
#        'text': 'Lyon, Auvergne-Rhone-Alpes, France'},
#       'school': 'École Normale Supérieure',
#       'start_date': {'date': '2002-01-01T00:00:00', 'text': '2002'},
#       'title': 'Reçu 3e, également admis à'},
#      {'description': '',
#       'end_date': {'date': '2002-01-01T00:00:00', 'text': '– 2002'},
#       'id': 'c29eaf69eb61bd85e37dfc4b0c744a721f97d463',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': 'Paris',
#          'city_district': None,
#          'country': 'FRA',
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': '75001',
#          'road': None,
#          'staircase': None,
#          'state': 'Ile-de-France',
#          'state_district': 'Paris',
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': 'https://www.google.com/maps/place/48.85718,2.34141',
#         'is_correct': True,
#         'lat': 48.85718,
#         'lng': 2.34141,
#         'text': 'Paris, Ile-de-France, France'},
#        'geopoint': {'lat': 48.85718, 'lon': 2.34141},
#        'text': 'Paris, Ile-de-France, France'},
#       'school': 'Lycée Louis le Grand',
#       'start_date': {'date': '2000-01-01T00:00:00', 'text': '2000'},
#       'title': 'Classes préparatoires'},
#      {'description': '    Mention Très Bien , félicitations du jury .\nConcours général mention régionale en mathématiques .',
#       'end_date': {'date': None, 'text': None},
#       'id': 'a20f62468115d4dd8bbbec8a7d34aab7c8ef09ad',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'school': None,
#       'start_date': {'date': '2000-01-01T00:00:00', 'text': '2000'},
#       'title': 'Baccalauréat'}],
#     'educations_duration': 11.005479452054795,
#     'email': {'text': None},
#     'experiences': [{'company': None,
#       'description': '  - Senior Data Scientist , Dataiku . Valorisation des données ( analyse prédictive ) , formation , sup\nport client , documentation , avant - vente . Machine Learning , Python , Big data , Hadoop , Hive .',
#       'end_date': {'date': '2014-01-01T00:00:00', 'text': '2014'},
#       'id': '215ae1b5ef95d0df91c6be296175272abbeec1ed',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': None, 'text': None},
#       'title': ''},
#      {'company': 'Criteo',
#       'description': "  –       Amélioration de la précision d ' algorithmes d ' apprentissage statis\ntique large échelle , notamment génération , analyse et sélection de nouvelles données . Auto\nmatisation du workflow . C # ( . Net ) , Java , Hadoop , Git , Unit testing , Agile",
#       'end_date': {'date': '2014-01-01T00:00:00', 'text': '2014'},
#       'id': '6f68ba93519c9ad75382858bc85ab8f367741744',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': '2012-01-01T00:00:00', 'text': '2012'},
#       'title': 'Software engineer'},
#      {'company': 'Eonos Investment Technologies',
#       'description': '        Apprentissage statistique et finance .\nOCaml ( programmation fonctionnelle comme F # ) , Python , R , Linux',
#       'end_date': {'date': '2012-01-01T00:00:00', 'text': '- 2012'},
#       'id': '1b09b2f314a6a902d822dac6cc67dd4b1a5c1c2c',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': '2011-01-01T00:00:00', 'text': '2011'},
#       'title': 'Ingénieur - chercheur'},
#      {'company': 'INRIA CNRS',
#       'description': '  –     CDD ) , INRIA et CNRS , \nMesure , modélisation ( théorique et pratique ) et simulation de systèmes complexes et grands\ngraphes ( e . g . réseaux sociaux , Twitter ) . Analyse des masses de données et leur dynamique .\nListe de publications : www . rouquier . org / jb / research / publications . php',
#       'end_date': {'date': '2011-01-01T00:00:00', 'text': '2011'},
#       'id': '09c07caaf49e2d42eda882839c3d716025e2121f',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': 'Bordeaux',
#          'city_district': 'Bordeaux Maritime',
#          'country': 'FRA',
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': '33300',
#          'road': 'Passage de Paris',
#          'staircase': None,
#          'state': 'Nouvelle-Aquitaine',
#          'state_district': 'Gironde',
#          'suburb': 'Bordeaux Maritime',
#          'unit': None,
#          'world_region': None},
#         'gmaps': 'https://www.google.com/maps/place/44.85565,-0.57409',
#         'is_correct': True,
#         'lat': 44.85565,
#         'lng': -0.57409,
#         'text': 'Passage de Paris, 33300 Bordeaux, France'},
#        'geopoint': {'lat': 44.85565, 'lon': -0.57409},
#        'text': 'Passage de Paris, 33300 Bordeaux, France'},
#       'start_date': {'date': '2009-01-01T00:00:00', 'text': '2009'},
#       'title': 'Chercheur postdoctorant i. e'},
#      {'company': 'École Normale Supérieure de Lyon',
#       'description': "        Dont enseignement .\n2003 – 2007 Rédaction , relectures scientifiques et typographiques ,\nÉditions H & K , Annales des concours d ' entrée aux grandes écoles .",
#       'end_date': {'date': '2008-01-01T00:00:00', 'text': '- 2008'},
#       'id': '8b72db2344de79546a2295fda89ef99283e67317',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': None,
#          'city_district': None,
#          'country': None,
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': None,
#          'road': None,
#          'staircase': None,
#          'state': None,
#          'state_district': None,
#          'suburb': None,
#          'unit': None,
#          'world_region': None},
#         'gmaps': None,
#         'is_correct': None,
#         'lat': None,
#         'lng': None,
#         'text': None},
#        'geopoint': {'lat': None, 'lon': None},
#        'text': None},
#       'start_date': {'date': '2005-01-01T00:00:00', 'text': '2005'},
#       'title': 'Chercheur doctorant informatique'},
#      {'company': None,
#       'description': "– Vulgarisateur : notamment Science en fête ,  Bleu , articles ,\n–   pour Veolia : conception d ' un modèle de ville générique , intégré , à grande échelle ,\n– Formateur LATEX ( sessions de 2 ou 3 jours , 8 stagiaires )",
#       'end_date': {'date': None, 'text': None},
#       'id': '8d539cbed4c2e0ad22fc7584d6c04116ae94ae57',
#       'location': {'geocoder': {'fields': {'category': None,
#          'city': "L'Isle-sur-la-Sorgue",
#          'city_district': 'Le Grand Palais',
#          'country': 'FRA',
#          'country_region': None,
#          'entrance': None,
#          'house': None,
#          'house_number': None,
#          'island': None,
#          'level': None,
#          'near': None,
#          'po_box': None,
#          'postcode': '84800',
#          'road': None,
#          'staircase': None,
#          'state': "Provence-Alpes-Cote d'Azur",
#          'state_district': 'Vaucluse',
#          'suburb': 'Le Grand Palais',
#          'unit': None,
#          'world_region': None},
#         'gmaps': 'https://www.google.com/maps/place/43.88248,5.07193',
#         'is_correct': True,
#         'lat': 43.88248,
#         'lng': 5.07193,
#         'text': "Le Grand Palais, L'Isle-sur-la-Sorgue, Provence-Alpes-Cote d'Azur, France"},
#        'geopoint': {'lat': 43.88248, 'lon': 5.07193},
#        'text': "Le Grand Palais, L'Isle-sur-la-Sorgue, Provence-Alpes-Cote d'Azur, France"},
#       'start_date': {'date': None, 'text': None},
#       'title': 'Consultant'}],
#     'experiences_duration': 8.002739726027396,
#     'interests': [{'name': "squash ; -\nContributeur à OpenStreetMap ( plan d ' un village , outil statistique",
#       'value': None},
#      {'name': 'Guitare classique', 'value': None},
#      {'name': 'composition', 'value': None},
#      {'name': 'Sports', 'value': None},
#      {'name': 'jonglage', 'value': None},
#      {'name': '; -\nMusique ( piano', 'value': None},
#      {'name': 'guitare', 'value': None},
#      {'name': 'pied , ski', 'value': None},
#      {'name': 'photographie , cuisine , bricolage', 'value': None},
#      {'name': 'Magie', 'value': None},
#      {'name': 'piano', 'value': None},
#      {'name': 'chorale', 'value': None},
#      {'name': 'fond ( skating ) , badminton', 'value': None},
#      {'name': 'musique', 'value': None},
#      {'name': 'solfège', 'value': None},
#      {'name': 'stratégie', 'value': None}],
#     'location': {'geocoder': {'fields': {'category': None,
#        'city': 'Jean',
#        'city_district': None,
#        'country': 'USA',
#        'country_region': None,
#        'entrance': None,
#        'house': None,
#        'house_number': None,
#        'island': None,
#        'level': None,
#        'near': None,
#        'po_box': None,
#        'postcode': '89019',
#        'road': None,
#        'staircase': None,
#        'state': 'NV',
#        'state_district': 'Clark',
#        'suburb': None,
#        'unit': None,
#        'world_region': None},
#       'gmaps': 'https://www.google.com/maps/place/35.77921,-115.32509',
#       'is_correct': True,
#       'lat': 35.77921,
#       'lng': -115.32509,
#       'text': 'Jean, NV, United States'},
#      'geopoint': {'lat': 35.77921, 'lon': -115.32509},
#      'text': 'Jean, NV, United States'},
#     'name': {'first_name': 'Rouquier', 'last_name': '', 'text': 'Rouquier'},
#     'profile_id': 'c9579e96622e96ced35c2198895edaa144bd605c',
#     'skills': [{'is_predicted': False,
#       'name': 'R & D',
#       'type': None,
#       'value': None},
#      {'is_predicted': False, 'name': 'recherche', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Anglais', 'type': None, 'value': None},
#      {'is_predicted': False, 'name': 'Allemand', 'type': None, 'value': None}],
#     'source_id': '8ce469e228fcdec508209023f525616f1b464597',
#     'summary': 'Formation et distinctions',
#     'tags': [{'name': 'email', 'value': 'test@test.com'},
#      {'name': 'referrer', 'value': None}],
#     'team_id': 'd57948095e4a842ff5436480f382f4b527b94a09',
#     'text': {'ar': '',
#      'bg': '',
#      'bn': '',
#      'ca': '',
#      'cjk': '',
#      'cs': '',
#      'da': '',
#      'de': '',
#      'el': '',
#      'en': '',
#      'es': '',
#      'eu': '',
#      'fa': '',
#      'fi': '',
#      'fr': "jean - baptiste rouquier\njean - baptiste . rouquier @ ens - lyon . org\n33 ans\nexpérience professionnelle\n2014 - senior data scientist , dataiku . valorisation des données ( analyse prédictive ) , formation , sup\nport client , documentation , avant - vente . machine learning , python , big data , hadoop , hive .\n2012 – 2014 software engineer , criteo . amélioration de la précision d ' algorithmes d ' apprentissage statis\ntique large échelle , notamment génération , analyse et sélection de nouvelles données . auto\nmatisation du workflow . c # ( . net ) , java , hadoop , git , unit testing , agile\n2011 - 2012 ingénieur - chercheur , eonos investment technologies . apprentissage statistique et finance .\nocaml ( programmation fonctionnelle comme f # ) , python , r , linux\n2009 – 2011 chercheur postdoctorant ( i . e . cdd ) , inria et cnrs , bordeaux et paris .\nmesure , modélisation ( théorique et pratique ) et simulation de systèmes complexes et grands\ngraphes ( e . g . réseaux sociaux , twitter ) . analyse des masses de données et leur dynamique .\nliste de publications : www . rouquier . org / jb / research / publications . php\n2005 - 2008 chercheur doctorant ( informatique ) , école normale supérieure de lyon . dont enseignement .\n2003 – 2007 rédaction , relectures scientifiques et typographiques ,\néditions h & k , annales des concours d ' entrée aux grandes écoles .\ndivers\n– vulgarisateur : notamment science en fête , grand palais , france bleu , articles ,\n– consultant pour veolia : conception d ' un modèle de ville générique , intégré , à grande échelle ,\n– formateur latex ( sessions de 2 ou 3 jours , 8 stagiaires )\ncompétences\ngrâce à mes postes en recherche puis r & d , j ' ai appris à :\n— expliquer clairement des concepts abstraits à des spécialistes / grand public / étudiants , à entre une et\ncent personnes , au travers d ' un exposé formel avec transparents / articles écrits / conversation informelle ,\n– apprendre vite et comprendre en profondeur les sujet théoriques difficiles ,\n– travailler en équipes interdisciplinaires et internationales ( avec des physiciens , mathématiciens , géo\ngraphes , biologistes , développeurs ) , motiver les membres de l ' équipe , organiser un colloque ,\n— travailler de façon automnome en définissant les bonnes questions à résoudre , avec rigueur et créativité .\nthéoriques expert en algorithmes , dont structures de données . expérimenté en probabilités , modélisation ,\ngraphes . culture générale en informatique : théorie des jeux , recherche opérationnelle , optimisation combina\ntoire , logique , paradigmes de programmation , statistiques , etc .\nlangues\nanglais : toeic 990 / 990 .\nallemand : compréhension écrite ( 10 ans de cours , oral réactivable en quelques mois ) .\ndivers\nattestation de formation aux premiers secours . brevet d ' aptitude aux fonctions d ' animateur .\nformation et distinctions\n2011 admis chargé de recherche ( fonctionnaire ) , inra .\n2004 – 2005 master parisien de recherche informatique . 68 / 50 ( 1er aux examens ) , mention très bien .\n2002 – 2004 école normale supérieure , lyon . reçu 3e , également admis à l ' ens ulm et polytechnique .\n2000 – 2002 lycée louis le grand , paris . classes préparatoires .\n2000 baccalauréat . mention très bien , félicitations du jury .\nconcours général mention régionale en mathématiques .\n1989 – 1999 classes à horaires aménagés musique guitare classique ( 11 ans d ' études ) , piano ( 12 ans ) ,\nsolfège ( 11 ans ) , chorale ( 6 ans ) , composition ( 4 ans ) .\nloisirs\n— magie ( président du club local , prestations rémunérées : 12decoeur . fr ) , jonglage et cirque ( 10 ans ) ; -\nmusique ( piano et guitare classiques ) , photographie , cuisine , bricolage et loisirs créatifs ;\n– nouveaux jeux de plateau , souvent de stratégie et réflexion ;\n— sports : course à pied , ski : piste et fond ( skating ) , badminton et squash ; -\ncontributeur à openstreetmap ( plan d ' un village  ...
#      'ga': '',
#      'gl': '',
#      'hi': '',
#      'hu': '',
#      'hy': '',
#      'id': '',
#      'it': '',
#      'ku': '',
#      'lt': '',
#      'lv': '',
#      'nl': '',
#      'no': '',
#      'pt': '',
#      'pt-BR': '',
#      'ro': '',
#      'ru': '',
#      'sv': '',
#      'th': '',
#      'tr': ''},
#     'urls': {'from_resume': [], 'picture': None},
#     'uuid': 'SfnAhHJpEeq0wAJCrBEAAg'}],
#   'predictions': [[0.45924076437950134, 0.540759265422821],
#    [0.5466413497924805, 0.4533586800098419],
#    [0.5466413497924805, 0.4533586800098419]]}}

# %% [markdown]
# # GET /profile/reasoning

# %% [markdown]
# # GET /profile/embedding

# %% [markdown]
# # PATCH /profile/feedback
