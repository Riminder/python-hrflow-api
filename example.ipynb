# %% [markdown]
# !pip install hrflow

# %%
import hrflow as hf
from pprint import pprint
client = hf.Client(api_key="ask_cbe04b31bde4c51c6bf0d320d4b285c2")

# %%
# %%time
result = client.source.list()
pprint(result)
# Out:
# https://www.rimstaging.net/sf/public/api/v1.0/sources
# {'code': 200,
#  'count': 30,
#  'data': [{'archive': False,
#            'date_creation': {'date': '2020-03-10 18:17:08.000000',
#                              'timezone': 'UTC',
#                              'timezone_type': 3},
#            'name': 'javascript-test',
#            'source_id': '1c39c4ad90cbef5ecfc56eb4b5111ab778931119',
#            'stats': {'total_profiles': '0'},
#            'sub_type': 'api',
#            'type': 'api'},
#           {'archive': False,
#            'date_creation': {'date': '2020-03-10 18:10:06.000000',
#                              'timezone': 'UTC',
#                              'timezone_type': 3},
#            'name': 'folder-test',
#            'source_id': 'd94bc625473bff35141ce37bdf66af844b6ec7bf',
#            'stats': {'total_profiles': '2'},
#            'sub_type': 'folder',
#            'type': 'folder'},
#           {'archive': False,
# ...

# %%
# %%time
result = client.profile.list(source_ids=["d94bc625473bff35141ce37bdf66af844b6ec7bf"])
pprint(result)
# Out:
# https://www.rimstaging.net/sf/public/api/v1.0/profiles/searching
# {'code': 200,
#  'count': 2,
#  'data': {'predictions': [],
#           'profiles': [{'date_reception': '2020-03-10T18:10:32',
#                         'educations': [{'description': 'electronics at the age '
#                                                        'of 7 , got his '
#                                                        'baccalaureate at Lycée '
#                                                        'AL',
#                                         'end_date': {'date': None,
#                                                      'text': None},
#                                         'id': '2f49061c0b8b074278ca6bcd7d7da1dd2d576b82',
#                                         'location': {'geocoder': {'fields': {'category': None,
#                                                                              'city': None,
# ...

# %%
# %%time
import os
result = client.profile.add(source_id="1c39c4ad90cbef5ecfc56eb4b5111ab778931119", profile_type="file", file_path="../data/cv.pdf")
                        #, profile_reference="",timestamp_reception=None, training_metadata=[])
pprint(result)
# Out:
# {'code': 400, 'message': 'Bad request. Invalid profile_type:'}
# CPU times: user 27.6 ms, sys: 7.27 ms, total: 34.9 ms
# Wall time: 2.1 s
