# %% [markdown]
# # Import hrflow

# %%
import hrflow as hf

# %% [markdown]
# # Launch hrflow Client

# %%
client = hf.Client(api_secret="ask_d6774338ad024297a8ac5431614513c1")

# %% [markdown]
# # Profile Exporter

# %%
# %%time
res = client.exporter.get(source_ids=['2be272f86ae21c311a4e0ee9401092026de063fc'],
                          target='.')
res
# Out:
# 1 sources to export.
# ...
