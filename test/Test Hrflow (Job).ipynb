# %% [markdown]
# # Import hrflow

# %%
import hrflow

# %% [markdown]
# # Launch hrflow Client

# %%
client = hrflow.Client(api_secret="ask_d6774338ad024297a8ac5431614513c1")

# %% [markdown]
# # POST /job

# %%
# %%time
res = client.job.add_json(name="data engineer", agent_id="a5dde54d7aa9a2ce6d3b11250aaa139cda3c9add", 
                          job_reference="1123d345678d55506",
                          title="Data engineer", description="This job is made for you")
res
# Out:
# CPU times: user 12.4 ms, sys: 0 ns, total: 12.4 ms
# Wall time: 890 ms
# {'code': 201,
#  'message': 'Job file added',
#  'data': {'job_id': 'b61e9e0648c036f487178eaadf97f4a9311a6619',
#   'job_reference': '1123d345678d55506',
#   'name': 'data engineer',
#   'description': 'This job is made for you',
#   'query': {'skills': None,
#    'experiences_duration_min': -1,
#    'experiences_duration_max': 100,
#    'educations_duration_min': -1,
#    'educations_duration_max': 100,
#    'is_geo_loc': False,
#    'is_exp_geo_loc': False,
#    'is_edu_geo_loc': False,
#    'location_lat': None,
#    'location_lng': None,
#    'radius': None},
#   'agent': {'agent_id': 'a5dde54d7aa9a2ce6d3b11250aaa139cda3c9add',
#    'name': 'General Model',
#    'description': None,
#    'timestamp': {'date': '2020-03-24 14:07:36.000000',
#     'timezone_type': 3,
#     'timezone': 'UTC'}},
#   'notification': False,
#   'archive': False,
#   'date_creation': {'date': '2020-04-07 20:57:58.110032',
# ...

# %% [markdown]
# # GET /jobs/searching

# %%
# %%time
client.job.search()
# Out:
# CPU times: user 11.6 ms, sys: 0 ns, total: 11.6 ms
# Wall time: 2.94 s
# {'code': 200,
#  'page': 1,
#  'maxPage': 1,
#  'count': 19,
#  'total': 19,
#  'message': 'Job list',
#  'data': [{'job_id': '09e2e17d06266e6d299d7783bb61565e12d250ed',
#    'job_reference': 'tesgeotetzettqseg',
#    'name': 'Neutral new test dawg',
#    'description': '',
#    'query': {'skills': [],
#     'experiences_duration_min': -100000000000,
#     'experiences_duration_max': 100000000000,
#     'educations_duration_min': -100000000000,
#     'educations_duration_max': 100000000000,
#     'is_geo_loc': False,
#     'is_exp_geo_loc': False,
#     'is_edu_geo_loc': True,
#     'location_lat': 34.0361152,
#     'location_lng': -6.7480954,
#     'radius': 10000},
#    'agent': [],
#    'notification': False,
#    'archive': False,
#    'date_creation': {'date': '2019-02-05 16:59:04.000000',
#     'timezone_type': 3,
#     'timezone': 'UTC'},
# ...

# %% [markdown]
# # GET /jobs/scoring

# %% [markdown]
# # GET /job/parsing

# %%
client.job.parsing.get(job_id="8b10a6c08d89117628df6f57a690fd18d335f6c2")
# Out:
# {'code': 200,
#  'message': 'Job parsing',
#  'data': {'job_id': '8b10a6c08d89117628df6f57a690fd18d335f6c2',
#   'job_reference': '1123d3456578d55506',
#   'name': 'data engineer',
#   'description': 'This job is made for you',
#   'query': {'skills': [],
#    'experiences_duration_min': -1,
#    'experiences_duration_max': 100,
#    'educations_duration_min': -1,
#    'educations_duration_max': 100,
#    'is_geo_loc': False,
#    'is_exp_geo_loc': False,
#    'is_edu_geo_loc': False,
#    'location_lat': None,
#    'location_lng': None,
#    'radius': None},
#   'agent': {'agent_id': 'a5dde54d7aa9a2ce6d3b11250aaa139cda3c9add',
#    'name': 'General Model',
#    'description': None,
#    'timestamp': {'date': '2020-03-24 14:07:36.000000',
#     'timezone_type': 3,
#     'timezone': 'UTC'}},
#   'notification': False,
#   'archive': False,
#   'date_creation': {'date': '2020-04-07 20:47:28.000000',
#    'timezone_type': 3,
#    'timezone': 'UTC'}}}

# %% [markdown]
# # GET /job/embedding

# %%
client.job.embedding.get(job_id="b61e9e0648c036f487178eaadf97f4a9311a6619")
# Out:
# {'code': 200,
#  'message': 'Job embedding',
# ...
